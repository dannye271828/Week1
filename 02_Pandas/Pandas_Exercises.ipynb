# %% [markdown]
# # Pandas Exercises

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/MedlyticsUniversal/Data/main/Week1/diabetes.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']

# %% [markdown]
# Read in csv above to a Pandas DataFrame named `data`.

# %%
# YOUR CODE HERE
data = pd.read_csv(url, names=names)
data.head()
# Out:
#    preg  plas  pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1

# %% [markdown]
# Print out the age and class of the 100th patient.

# %%
# YOUR CODE HERE
print(data.loc[99, ['age', 'class']])
# Out:
# age      31.0
# class     1.0
# Name: 99, dtype: float64

# %% [markdown]
# Write code to figure out how many people are classified as not having diabetes (class = 0).

# %%
# YOUR CODE HERE
num_no_diabetes = data[data['class'] == 0].shape[0]
print(num_no_diabetes)
# Out:
# 500

# %% [markdown]
# Write code to figure out how many people are classified as having diabetes (class = 1).

# %%
# YOUR CODE HERE
num_diabetes = data[data['class'] == 1].shape[0]
print(num_diabetes)
# Out:
# 268

# %% [markdown]
# What percent of patients have diabetes in this study?

# %%
# YOUR CODE HERE
percent_diabetes = (num_diabetes / data.shape[0]) * 100
print(percent_diabetes)
# Out:
# 34.89583333333333

# %% [markdown]
# Print out the `"pres"` and `"class"` (no other columns) for the first 5 people.

# %%
# YOUR CODE HERE
print(data.loc[:4, ['pres', 'class']])
# Out:
#    pres  class
# 0    72      1
# 1    66      0
# 2    64      1
# 3    66      0
# 4    40      1

# %% [markdown]
# Run the cell below. It will print out the correlation among the columns.

# %%
data.corr()
# Out:
#            preg      plas      pres      skin      test      mass      pedi  \
# preg   1.000000  0.129459  0.141282 -0.081672 -0.073535  0.017683 -0.033523
# plas   0.129459  1.000000  0.152590  0.057328  0.331357  0.221071  0.137337
# pres   0.141282  0.152590  1.000000  0.207371  0.088933  0.281805  0.041265
# skin  -0.081672  0.057328  0.207371  1.000000  0.436783  0.392573  0.183928
# test  -0.073535  0.331357  0.088933  0.436783  1.000000  0.197859  0.185071
# mass   0.017683  0.221071  0.281805  0.392573  0.197859  1.000000  0.140647
# pedi  -0.033523  0.137337  0.041265  0.183928  0.185071  0.140647  1.000000
# age    0.544341  0.263514  0.239528 -0.113970 -0.042163  0.036242  0.033561
# class  0.221898  0.466581  0.065068  0.074752  0.130548  0.292695  0.173844
#
#             age     class
# preg   0.544341  0.221898
# plas   0.263514  0.466581
# pres   0.239528  0.065068
# skin  -0.113970  0.074752
# test  -0.042163  0.130548
# mass   0.036242  0.292695
# pedi   0.033561  0.173844
# age    1.000000  0.238356
# class  0.238356  1.000000

# %% [markdown]
# What column has the highest correlation with class? Find the mean() value of that column.

# %%
# YOUR CODE HERE
correlation_with_class = data.corr()['class'].drop('class')
highest_corr_column = correlation_with_class.idxmax()
highest_corr_mean = data[highest_corr_column].mean()
print(highest_corr_column, highest_corr_mean)
# Out:
# plas 120.89453125

# %% [markdown]
# Create a new DataFrame with only people that are above the mean found in the above cell.

# %%
# YOUR CODE HERE
above_mean_df = data[data[highest_corr_column] > highest_corr_mean]
above_mean_df.head()
# Out:
#    preg  plas  pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 2     8   183    64     0     0  23.3  0.672   32      1
# 4     0   137    40    35   168  43.1  2.288   33      1
# 8     2   197    70    45   543  30.5  0.158   53      1
# 9     8   125    96     0     0   0.0  0.232   54      1

# %% [markdown]
# Create a new DataFrame that only includes people who are above the average value for each column in the dataset. In other words, find the average value for each column, then find which users have values above all of these average column values.

# %%
# YOUR CODE HERE
average_values = data.mean()
above_average_df = data[(data > average_values).all(axis=1)]
above_average_df.head()
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 43      9   171   110    24   240  45.4  0.721   54      1
# 152     9   156    86    28   155  34.3  1.189   42      1
# 159    17   163    72    41   114  40.9  0.817   47      1
# 175     8   179    72    42   130  32.7  0.719   36      1
# 206     8   196    76    29   280  37.5  0.605   57      1

# %% [markdown]
# *Note: The next 3 problems were not explicitly shown in our tutorial—being able to effectively Google and look through documentation is a very important coding tool!* ¯\\\_(ツ)_/¯

# %% [markdown]
# Ignoring the index (resetting the index to 0) and using the DataFrame from the cell above, sort the values based on `"skin"`, `"test"`, and `"pedi"` values in ascending order. Please write this in one line.

# %%
# YOUR CODE HERE
sorted_df = above_average_df.sort_values(by=['skin', 'test', 'pedi']).reset_index(drop=True)
sorted_df.head()
# Out:
#    preg  plas  pres  skin  test  mass   pedi  age  class
# 0     7   181    84    21   192  35.9  0.586   51      1
# 1     9   171   110    24   240  45.4  0.721   54      1
# 2    11   138    74    26   144  36.1  0.557   50      1
# 3     5   187    76    27   207  43.6  1.034   53      1
# 4    11   155    76    28   150  33.3  1.353   51      1

# %% [markdown]
# Now, let's find the 4 largest values for `"age"`.

# %%
# YOUR CODE HERE
largest_ages = data.nlargest(4, 'age')
print(largest_ages[['age']])
# Out:
#      age
# 459   81
# 453   72
# 666   70
# 123   69

# %% [markdown]
# Find the smallest 4 values for `"pedi"` and `"plas"` in reverse order (smallest to largest).

# %%
# YOUR CODE HERE
smallest_pedi_plas = data.nsmallest(4, ['pedi', 'plas']).sort_values(by=['pedi', 'plas'], ascending=True)
print(smallest_pedi_plas[['pedi', 'plas']])
# Out:
#       pedi  plas
# 268  0.078   102
# 180  0.084    87
# 149  0.085    90
# 567  0.085    92

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=67231ff1-13ba-4f0b-99c2-0fe76b4d3844' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
